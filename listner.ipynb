# %%
from aiogram import Bot, types
from aiogram.dispatcher import Dispatcher
from aiogram.utils import executor
from aiogram.utils.markdown import text, code

import nest_asyncio

# %%
bot = Bot(token="1940696119:AAF38G-yHPA4ppyEb3quEW9lUQqnj-c4I6s")
dp = Dispatcher(bot)

# %%
@dp.message_handler()
async def echo_message(message: types.Message):

    print(f'message {message.text}\nfrom {message.from_user.id}\n\n')

# %%
# nest_asyncio.apply()
# __import__('IPython').embed()

# executor.start_polling(dp)

# %%
import json

with open('./timetable.json', 'r') as f:
            res_dict = json.load(f)

# %%
res_dict
# Out:
# {'нечетная': {'2': {'1': ['Ознакомительная практика',
#     'срс',
#     '',
#     'О-303,О-306,О-309,О-310,О-316,К-206'],
#    '2': ['Химическая технология', 'пр', 'Кацман Е.А.', 'К-7'],
#    '3': ['Химическая технология',
#     'лаб',
#     'Устюгов А.В., Пастухова Ж.Ю.',
#     'О-505,О-506,О-504'],
#    '4': ['Химическая технология',
#     'лаб',
#     'Устюгов А.В., Пастухова Ж.Ю.',
#     'О-505,О-506,О-504'],
#    '5': ['Русский язык и культура речи', 'пр', 'Макоева Ф.С.', 'Л-106'],
#    '6': []},
#   '1': {'1': [],
#    '2': [],
#    '3': ['Физическая химия', 'лек', 'Флид В.Р,', 'Д'],
#    '4': ['Русский язык и культура речи', 'лек', 'Макоева Ф.С.', 'Д'],
#    '5': [],
#    '6': []},
#   '5': {'1': ['Физико-химические методы анализа',
#     'лаб',
#     'Лазов М.А., Дятлов В.А.',
#     'О-225'],
#    '2': ['Физико-химические методы анализа',
#     'лаб',
#     'Лазов М.А., Дятлов В.А.',
#     'О-225'],
#    '3': ['Физико-химические методы анализа', 'пр', 'Лазов М.А.', 'К-6'],
#    '4': ['Физическая химия', 'пр', 'Каримов/Флид', 'К-4'],
#    '5': ['Ознакомительная практика',
#     'срс',
#     '',
#     'О-303,О-306,О-309,О-310,О-316,К-206'],
#    '6': []},
#   '3': {'1': ['Военная подготовка', '', '', ''],
#    '2': [],
#    '3': [],
#    '4': [],
#    '5': [],
#    '6': []},
#   '6': {'1': ['Химическая технология', 'лек', 'Путин А.Ю.', 'Д'],
#    '2': ['Химическая технология', 'лек', 'Путин А.Ю.', 'Д'],
#    '3': ['Физико-химические методы анализа',
#     'лек',
#     'Ищенко А.А. / Дятлов В.А.',
#     'Д'],
#    '4': [],
#    '5': ['Химия комплексных соединений', 'лек', 'Жижин К.Ю.', 'Д'],
#    '6': []},
#   '4': {'1': ['Химия комплексных соединений', 'лаб', 'Матвеев Е.Ю.', 'К-4'],
#    '2': ['Химия комплексных соединений', 'лаб', 'Матвеев Е.Ю.', 'К-4'],
#    '3': ['Физическая химия', 'лаб', 'Каримов/Флид', 'О-105/О-137'],
#    '4': ['Физическая химия', 'лаб', 'Каримов/Флид', 'О-105/О-137'],
#    '5': ['Химия комплексных соединений', 'пр', 'Матвеев Е.Ю.', 'К-6'],
#    '6': []}},
#  'четная': {'2': {'1': ['Химическая технология', 'пр', 'Кацман Е.А.', 'К-7'],
#    '2': ['Химическая технология', 'пр', 'Кацман Е.А.', 'К-7'],
#    '3': ['Химическая технология',
#     'лаб',
#     'Устюгов А.В., Пастухова Ж.Ю.',
#     'О-505,О-506,О-504'],
#    '4': ['Химическая технология',
#     'лаб',
#     'Устюгов А.В., Пастухова Ж.Ю.',
#     'О-505,О-506,О-504'],
#    '5': ['Русский язык и культура речи', 'пр', 'Макоева Ф.С.', 'Л-106'],
#    '6': []},
#   '1': {'1': [],
#    '2': ['Физическая химия', 'лек', 'Флид В.Р,', 'Д'],
#    '3': ['Физическая химия', 'лек', 'Флид В.Р,', 'Д'],
#    '4': [],
#    '5': [],
#    '6': []},
#   '5': {'1': ['Физико-химические методы анализа',
#     'лаб',
#     'Лазов М.А., Дятлов В.А.',
#     'О-225'],
#    '2': ['Физико-химические методы анализа',
#     'лаб',
#     'Лазов М.А., Дятлов В.А.',
#     'О-225'],
#    '3': ['Физико-химические методы анализа', 'пр', 'Лазов М.А.', 'К-6'],
#    '4': ['Физическая химия', 'пр', 'Каримов/Флид', 'К-4'],
#    '5': ['Ознакомительная практика', 'срс', '', ''],
#    '6': []},
#   '3': {'1': [], '2': [], '3': [], '4': [], '5': [], '6': []},
#   '6': {'1': [],
#    '2': ['Химическая технология', 'лек', 'Путин А.Ю.', 'Д'],
#    '3': ['Физико-химические методы анализа',
#     'лек',
#     'Ищенко А.А. / Дятлов В.А.',
#     'Д'],
#    '4': ['Физико-химические методы анализа',
#     'лек',
#     'Ищенко А.А. / Дятлов В.А.',
#     'Д'],
#    '5': ['Химия комплексных соединений', 'лек', 'Жижин К.Ю.', 'Д'],
#    '6': []},
#   '4': {'1': ['Химия комплексных соединений', 'лаб', 'Матвеев Е.Ю.', 'К-4'],
#    '2': ['Химия комплексных соединений', 'лаб', 'Матвеев Е.Ю.', 'К-4'],
#    '3': ['Физическая химия', 'лаб', 'Каримов/Флид', 'О-105/О-137'],
#    '4': ['Физическая химия', 'лаб', 'Каримов/Флид', 'О-105/О-137'],
#    '5': ['Химия комплексных соединений', 'пр', 'Матвеев Е.Ю.', 'К-6'],
#    '6': []}}}
